# %% [markdown]
# # FINDING SHORT TANDEM REPEATS

# %%
#fasta file was read with UGENE
#content from fasta was cleaned using sequence_cleaner (http://www.cellbiol.com/scripts/cleaner/dna_protein_sequence_cleaner.php)
#read the text file containing the sequence and print it as a string
with open('mtDapma3clones_MH683636_1.txt', 'r') as sequence:
    seq = sequence.readlines()
    seq = ''.join(seq)
    #print(seq)

# %%
#sample for debugging
#seq = 'ATGATGATGATGATATAT'

# %%
#create a dictionary for combinations of nucleotides that could appear as a repeat; di and tri
repeatsDict = {
    "dinucleotides": ["AT","TA", "CG", "GC", "AA", "TT",
    "CC", "GG", "AC", "AG", "TC", "TG", "CA", "CT", "GA", "GT"],
    
    "trinucleotides": ["AAA","AAT","AAC","AAG","ATG","ATC","ATA",
    "ATT","ACA","ACT","ACC","ACG","AGA","AGT","AGC","AGG","TTT",
    "TTC","TTA","TTG","TCT","TCC", "TCA","TCG","TAT","TAC","TGT", 
    "TGC","TGG","CTT","CTC","CTA","CTG","CCT", "CCC", "CCA","CCG",
    "CAT","CAC","CAA", "CAG", "CGT","CGC","CGA","CGG","GTT","GTC",
    "GTA","GTG", "GCT","GCC","GCA","GCG","GAT","GAC","GAA","GAG",
    "GGT","GGC","GGA","GGG"],
    
    "stop": ["TAG","TAA","TGA"]
    }

#print(repeatsDict["stop"])

# %%
#import library with built-in function of finding mutliple substrings in a string
import re

# %%
#import library with built-in function of calculating binomial distribution
from scipy import stats

# %%
#BINOMIAL DISTRIBUTION
# binom(k, n, p)
#Define the number of successes (k), number of trials (n), and expected probability success (p).
# k = total STRs; total
# n = len of seq / 2 or 3; len(seq)/len(diN/tri/stC)... enter the diN/triN/stC as n
# p = freqX of each possible STR; freqX(diN/triN/stC)

# %%
#frequencey of nucleotides (Pb)
def Pb(nucl):
    return seq.count(nucl)/len(seq)

fA = Pb('A')
fT = Pb('T')
fG = Pb('G')
fC = Pb('C')
#print(fA, fT, fG, fC)
#print(fA+fT+fG+fC)

def freqX(STRs): 
    x = 1
    for i in STRs:
        #print(i)
        if i == 'A':
            x *= fA
        elif i == 'T':
            x *= fT
        elif i == 'G':
            x *= fG
        elif i == 'C':
            x *= fC
    #print(STRs, "expected freq:", x)
    return x

#freqX('TT')

# %%
def nTrials(STRs):
    n = len(seq)/len(STRs)
    return int(n)

#nTrials('TGA')

# %%
def binom(STRs, k, n, p):
    statBD = stats.binom.pmf(k, n, p)
    print( STRs, "binomial distribution, Pb:", statBD)
    
#binom('TGA', total, nTrials('TGA'), freqX('TGA'))

# %% [markdown]
# # RESULTS

# %%
#create a dictionary for all matching dinucleotides found and print position of all occurences of each dinucleotides
diNucl = {}
for i in repeatsDict["dinucleotides"]:
    match = re.finditer(pattern=i, string=seq)
    diNucl[i] = [index.start() for index in match]
#print(diNucl)

# %%
#for each item in the dinucleotides, find the positions showing at least 3 repeats 
for dn, diN in zip(diNucl.values(), diNucl.keys()):
    #print(diN)  
    
    total = 0
    count = 0
    x = 0
    # extend length by 2 to allow entire element to run, this is just a random number
    dn.extend((-7, -7))
    # iterate through the length of the selected dinucleotide
    while x < len(dn)-2:
        x += 1
        
        #for each item in the list of the selected dinucleotide
        for i in dn:
            # select for next 2, so that it can be identified as at least 3 repeats
            if i == dn[x]-2 and i == dn[x+1]-4:
                count += 1
                #print(i, count)

            # else check next 1 and preceeding 1   
            elif i == dn[x]-2 and i == dn[x-2]+2:
                count += 1
                #print(i, count)

            # else check preceeding 2   
            elif i == dn[x-2]+2 and i == dn[x-3]+4:
                count += 1
                #print(i, count)
                print(count, 'STRs ending at pos.', i+2)
                
                # add count to total, then reset counter 
                total += count
                count = 0
     
    # print only nucleotides with repeats
    if total > 0:
        print(diN, 'total STRs in the sequence :', total)
        
        # print binomial probability
        binom(diN, total, nTrials(diN), freqX(diN))
        print()
# Out:
# 3 STRs ending at pos. 2361
# 3 STRs ending at pos. 4132
# 3 STRs ending at pos. 4585
# 3 STRs ending at pos. 7029
# 3 STRs ending at pos. 11803
# 3 STRs ending at pos. 14809
# AT total STRs in the sequence : 18
# AT binomial distribution, Pb: 0.0
#
# 3 STRs ending at pos. 664
# 3 STRs ending at pos. 2360
# 3 STRs ending at pos. 7328
# 3 STRs ending at pos. 7962
# 3 STRs ending at pos. 10978
# 3 STRs ending at pos. 12360
# 3 STRs ending at pos. 13413
# 3 STRs ending at pos. 13673
# 3 STRs ending at pos. 14603
# 3 STRs ending at pos. 14810
# TA total STRs in the sequence : 30
# TA binomial distribution, Pb: 0.0
#
# 3 STRs ending at pos. 417
# 3 STRs ending at pos. 460
# 3 STRs ending at pos. 673
# 3 STRs ending at pos. 5820
# 3 STRs ending at pos. 6491
# 3 STRs ending at pos. 7009
# 3 STRs ending at pos. 7315
# 3 STRs ending at pos. 8019
# 3 STRs ending at pos. 8425
# 3 STRs ending at pos. 9020
# 3 STRs ending at pos. 9218
# 4 STRs ending at pos. 9295
# 3 STRs ending at pos. 9422
# 4 STRs ending at pos. 9485
# 3 STRs ending at pos. 9702
# 3 STRs ending at pos. 9844
# 4 STRs ending at pos. 10254
# 3 STRs ending at pos. 12425
# 3 STRs ending at pos. 13039
# 3 STRs ending at pos. 14282
# 3 STRs ending at pos. 14619
# 3 STRs ending at pos. 14997
# 3 STRs ending at pos. 15136
# AA total STRs in the sequence : 72
# AA binomial distribution, Pb: 6.259253754370236e-287
#
# 3 STRs ending at pos. 1116
# 4 STRs ending at pos. 1831
# 3 STRs ending at pos. 2072
# 3 STRs ending at pos. 2341
# 3 STRs ending at pos. 2630
# 3 STRs ending at pos. 2871
# 3 STRs ending at pos. 2919
# 4 STRs ending at pos. 3305
# 3 STRs ending at pos. 3794
# 3 STRs ending at pos. 3895
# 3 STRs ending at pos. 4117
# 3 STRs ending at pos. 5168
# 3 STRs ending at pos. 5911
# 3 STRs ending at pos. 5930
# 3 STRs ending at pos. 6017
# 3 STRs ending at pos. 6217
# 3 STRs ending at pos. 6988
# 3 STRs ending at pos. 7396
# 3 STRs ending at pos. 8174
# 4 STRs ending at pos. 8243
# 4 STRs ending at pos. 9992
# 3 STRs ending at pos. 10245
# 3 STRs ending at pos. 10322
# 3 STRs ending at pos. 10440
# 3 STRs ending at pos. 10783
# 3 STRs ending at pos. 11047
# 3 STRs ending at pos. 11108
# 3 STRs ending at pos. 11334
# 3 STRs ending at pos. 12732
# 4 STRs ending at pos. 13901
# 3 STRs ending at pos. 13909
# 3 STRs ending at pos. 14275
# 3 STRs ending at pos. 14561
# 3 STRs ending at pos. 15100
# TT total STRs in the sequence : 107
# TT binomial distribution, Pb: 1.6323159085159326e-246
#
# 3 STRs ending at pos. 380
# 3 STRs ending at pos. 1948
# 3 STRs ending at pos. 2019
# 3 STRs ending at pos. 8823
# 3 STRs ending at pos. 8911
# 3 STRs ending at pos. 11905
# 3 STRs ending at pos. 11983
# 3 STRs ending at pos. 12234
# CC total STRs in the sequence : 24
# CC binomial distribution, Pb: 6.369412043764192e-69
#
# 3 STRs ending at pos. 2301
# 3 STRs ending at pos. 2683
# 3 STRs ending at pos. 11380
# GG total STRs in the sequence : 9
# GG binomial distribution, Pb: 1.4577586981191431e-64
#
# 3 STRs ending at pos. 708
# 3 STRs ending at pos. 7746
# 3 STRs ending at pos. 8123
# 3 STRs ending at pos. 14116
# 3 STRs ending at pos. 15033
# AC total STRs in the sequence : 15
# AC binomial distribution, Pb: 5.803125182628009e-172
#
# 3 STRs ending at pos. 344
# 3 STRs ending at pos. 6908
# 3 STRs ending at pos. 9586
# 3 STRs ending at pos. 10373
# AG total STRs in the sequence : 12
# AG binomial distribution, Pb: 3.8375757719166864e-153
#
# 3 STRs ending at pos. 1588
# 3 STRs ending at pos. 2025
# 3 STRs ending at pos. 2393
# 3 STRs ending at pos. 9238
# TC total STRs in the sequence : 12
# TC binomial distribution, Pb: 2.2374729512669924e-175
#
# 3 STRs ending at pos. 7747
# CA total STRs in the sequence : 3
# CA binomial distribution, Pb: 1.024345275116083e-192
#
# 3 STRs ending at pos. 1099
# 4 STRs ending at pos. 2026
# CT total STRs in the sequence : 7
# CT binomial distribution, Pb: 9.330232850784228e-184
#
# 3 STRs ending at pos. 5840
# 3 STRs ending at pos. 6909
# 3 STRs ending at pos. 8432
# 3 STRs ending at pos. 9585
# 3 STRs ending at pos. 13990
# GA total STRs in the sequence : 15
# GA binomial distribution, Pb: 9.936686932983595e-149

# %%
#create a dictionary for all matching trinucleotides found and print position of all occurences of each trinucleotides
triNucl = {}
for i in repeatsDict["trinucleotides"]:
    match = re.finditer(pattern=i, string=seq)
    triNucl[i] = [index.start() for index in match]
#print(triNucl)

# %%
#for each item in the trinucleotides,  find the positions showing at least 3 repeats
for tn, triN in zip(triNucl.values(), triNucl.keys()):
    #print(triN)  
    
    total = 0
    count = 0
    x = 0
    # extend length by 2 values to allow entire element to run, this is just a random number
    tn.extend((-7, -7))
    # iterate through the length of the selected trinucleotides
    while x < len(tn)-2:
        x += 1
                
        #for each item in the list of the selected trinucleotides
        for i in tn:
            # select for next 2, so that it can be identified as at least 3 repeats
            if i == tn[x]-3 and i == tn[x+1]-6:
                count += 1
                #print(i, count)
            
            # else check next 1, and preceeding 1   
            elif i == tn[x]-3 and i == tn[x-2]+3:
                count += 1
                #print(i, count)
                
            # else check preceeding 2
            elif i == tn[x-2]+3 and i == tn[x-3]+6:
                count += 1
                #print(i, count)
                print(count, 'STRs ending at pos.', i+3)
                
                # add count to total, then reset counter 
                total += count
                count = 0
    
    # print only nucleotides with repeats
    if total > 0:
        print(triN, 'total STRs in the sequence :', total, )
        
        # print binomial probability
        binom(triN, total, nTrials(triN), freqX(triN))
        print()
# Out:
# 3 STRs ending at pos. 10255
# AAA total STRs in the sequence : 3
# AAA binomial distribution, Pb: 2.1859668044193605e-80
#
# 3 STRs ending at pos. 817
# 3 STRs ending at pos. 1048
# AAT total STRs in the sequence : 6
# AAT binomial distribution, Pb: 4.669242549912849e-75
#
# 4 STRs ending at pos. 818
# 3 STRs ending at pos. 8687
# ATA total STRs in the sequence : 7
# ATA binomial distribution, Pb: 1.3340228135702085e-73
#
# 3 STRs ending at pos. 4724
# TCT total STRs in the sequence : 3
# TCT binomial distribution, Pb: 7.30178260091153e-39
#
# 3 STRs ending at pos. 7695
# TAT total STRs in the sequence : 3
# TAT binomial distribution, Pb: 2.2231222767916222e-79

# %%
#create a dictionary for all matching stop codons found and print position of all occurences of each stop codons
stopCodons = {}
for i in repeatsDict["stop"]:
    match = re.finditer(pattern=i, string=seq)
    stopCodons[i] = [index.start() for index in match]
#print(stopCodons)

# %%
#for each item in the stop codons,  find the positions showing at least 3 repeats
for sc, stC in zip(stopCodons.values(), stopCodons.keys()):
    #print(stC)  
    
    total = 0
    count = 0
    x = 0
    
    # extend length by 2 values to allow entire element to run, this is just a random number
    sc.extend((-7,-7))
    # iterate through the length of the selected stop codon
    while x < len(sc)-2:
        x += 1
                
        #for each item in the list of the selected stop codon
        for i in sc:
            # select for next 2, so that it can be identified as at least 3 repeats
            if i == sc[x]-3 and i == sc[x+1]-6:
                count += 1
                #print(i, count)
            
            # else check next 1, and preceeding 1   
            elif i == sc[x]-3 and i == sc[x-2]+3:
                count += 1
                #print(i, count)
                
            # else check preceeding 2
            elif i == sc[x-2]+3 and i == sc[x-3]+6:
                count += 1
                #print(i, count)
                print(count, 'STRs ending at pos.', i+3)
                
                # add count to total, then reset counter 
                total += count
                count = 0
                
    # print only nucleotides with repeats
    if total > 0:
        print(stC, 'total STRs in the sequence :', total)
        
        # print binomial probability
        binom(stC, total, nTrials(stC), freqX(stC))
        print()
# Out:
# 4 STRs ending at pos. 819
# 3 STRs ending at pos. 1047
# 3 STRs ending at pos. 8688
# TAA total STRs in the sequence : 10
# TAA binomial distribution, Pb: 1.4803323638208016e-69
